# %%
pip install matplotlib
# Out:
# ...
#   Using cached pillow-12.1.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 46.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 46.6 MB/s  0:00:00
# ...
# Using cached pillow-12.1.0-cp310-cp310-macosx_11_0_arm64.whl (4.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("./StudentData.csv")
display(df)
# Out:
#        N  Gender  Age Address  Height  Weight    Eye  Medu  Fedu Fsize
# 0      1  Female   19       R     154     132   Blue     3     3   GT3
# 1      2  Female   17       U     190     118   Blue     3     2   GT3
# 2      3  Female   17       U     181     111   Blue     4     4   LE3
# 3      4  Female   17       R     144      66   Blue     2     3   GT3
# 4      5  Female   18       R     148      54   Blue     1     2   GT3
# ..   ...     ...  ...     ...     ...     ...    ...   ...   ...   ...
# 495  496    Male   18       R     141      86  Green     2     3   GT3
# 496  497    Male   17       U     173     139  Green     3     1   GT3
# 497  498    Male   18       U     154     145  Green     1     1   GT3
# 498  499    Male   18       U     168     148  Green     2     2   GT3
# 499  500    Male   17       R     178      92  Green     4     3   GT3
#
# [500 rows x 10 columns]

# %%
df=df.drop_duplicates()

# %%
long=pd.melt(df, id_vars=['N', 'name'], value_vars=['Q1','Q2','Q3','Q4'], var_name='quarter', value_name='clicks')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 long=pd.melt(df, id_vars=['N', 'name'], value_vars=['Q1','Q2','Q3','Q4'], var_name='quarter', value_name='clicks')
#
# File /opt/anaconda3/envs/dbmsl/lib/python3.10/site-packages/pandas/core/reshape/melt.py:74, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      70 if missing.any():
#      71     missing_labels = [
#      72         lab for lab, not_found in zip(labels, missing) if not_found
#      73     ]
# ---> 74     raise KeyError(
#      75         "The following id_vars or value_vars are not present in "
#      76         f"the DataFrame: {missing_labels}"
#      77     )
#      78 if value_vars_was_not_none:
#      79     frame = frame.iloc[:, algos.unique(idx)]
#
# ...
