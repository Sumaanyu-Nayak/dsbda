# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
csv_data=pd.read_csv("./market_data.csv")

# %%
print(csv_data)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
print(csv_data.head())
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
print(csv_data.head(10))
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
print(csv_data.tail())
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
print(csv_data.tail(8))
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8515        Baking Goods  157.5288            OUT018
# 8516              Others   58.7588            OUT018
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# ...

# %%
print(csv_data.tail(-4))
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 4              Household   53.8614            OUT013
# ...

# %%
print(csv_data.columns)
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
csv_data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
csv_data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
csv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
csv_data.values
# Out:
# array([['FDA15', 9.3, 'Low Fat', ..., 'Tier 1', 'Supermarket Type1',
#         3735.138],
#        ['DRC01', 5.92, 'Regular', ..., 'Tier 3', 'Supermarket Type2',
#         443.4228],
#        ['FDN15', 17.5, 'Low Fat', ..., 'Tier 1', 'Supermarket Type1',
#         2097.27],
#        ...,
#        ['NCJ29', 10.6, 'Low Fat', ..., 'Tier 2', 'Supermarket Type1',
#         1193.1136],
#        ['FDN46', 7.21, 'Regular', ..., 'Tier 3', 'Supermarket Type2',
#         1845.5976],
#        ['DRG01', 14.8, 'Low Fat', ..., 'Tier 1', 'Supermarket Type1',
#         765.67]], shape=(8523, 12), dtype=object)

# %%
csv_data.value_counts()
# Out:
# Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type     Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type        Item_Outlet_Sales
# DRA12            11.600       LF                0.000000         Soft Drinks   141.9154  OUT035             2004                       Small        Tier 2                Supermarket Type1  992.7078             1
# FDV35            19.500       Low Fat           0.128182         Breads        156.1314  OUT035             2004                       Small        Tier 2                Supermarket Type1  2792.3652            1
# FDV25            5.905        low fat           0.045614         Canned        221.5456  OUT013             1987                       High         Tier 3                Supermarket Type1  6852.4136            1
# ...

# %%
csv_data.ndim
# Out:
# 2

# %%
csv_data.size
# Out:
# 102276

# %%
csv_data.shape
# Out:
# (8523, 12)

# %%
csv_data.empty
# Out:
# False

# %%
print(csv_data["Item_Weight"])
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
csv_data.loc[5,'Outlet_Identifier']
# Out:
# 'OUT018'

# %%
csv_data.loc[5]
# Out:
# Item_Identifier                          FDP36
# Item_Weight                             10.395
# Item_Fat_Content                       Regular
# Item_Visibility                            0.0
# Item_Type                         Baking Goods
# Item_MRP                               51.4008
# Outlet_Identifier                       OUT018
# Outlet_Establishment_Year                 2009
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 3
# Outlet_Type                  Supermarket Type2
# Item_Outlet_Sales                     556.6088
# Name: 5, dtype: object

# %%
print(csv_data.loc[2:5])
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2           FDN15       17.500          Low Fat          0.01676
# 3           FDX07       19.200          Regular          0.00000
# 4           NCD19        8.930          Low Fat          0.00000
# 5           FDP36       10.395          Regular          0.00000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# ...

# %%
print(csv_data.iloc[5])
# Out:
# Item_Identifier                          FDP36
# Item_Weight                             10.395
# Item_Fat_Content                       Regular
# Item_Visibility                            0.0
# Item_Type                         Baking Goods
# Item_MRP                               51.4008
# Outlet_Identifier                       OUT018
# Outlet_Establishment_Year                 2009
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 3
# Outlet_Type                  Supermarket Type2
# Item_Outlet_Sales                     556.6088
# Name: 5, dtype: object

# %%
print(csv_data["Item_Visibility"].iloc[1])
# Out:
# 0.019278216

# %%
print("Shows data to 5th to less than 10th in a row:")
print(csv_data.iloc[5:10])
# Out:
# Shows data to 5th to less than 10th in a row:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 5  Baking Goods   51.4008            OUT018                       2009
# 6   Snack Foods   57.6588            OUT013                       1987
# 7   Snack Foods  107.7622            OUT027                       1985
# 8  Frozen Foods   96.9726            OUT045                       2002
# 9  Frozen Foods  187.8214            OUT017                       2007
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
print(csv_data[csv_data.Item_Type=='Frozen Foods'])
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 24             FDR28       13.850          Regular         0.025896
# 51             FDM40       10.195          Low Fat         0.159804
# 63             FDY40          NaN          Regular         0.150286
# ...              ...          ...              ...              ...
# 8477           FDC05       13.100          Regular         0.099343
# 8482           FDZ28       20.000          Regular         0.051702
# 8507           FDN28        5.880          Regular         0.030242
# 8511           FDF05       17.500          Low Fat         0.026980
# 8517           FDF53       20.750              reg         0.083607
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8     Frozen Foods   96.9726            OUT045                       2002
# ...

# %%
print(csv_data[(csv_data.Item_Type=='Frozen Foods') & (csv_data.Item_Weight>10)])
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 24             FDR28       13.850          Regular         0.025896
# 51             FDM40       10.195          Low Fat         0.159804
# 78             FDL04       19.000          Low Fat         0.112557
# ...              ...          ...              ...              ...
# 8461           FDB17       13.150          Low Fat         0.036672
# 8477           FDC05       13.100          Regular         0.099343
# 8482           FDZ28       20.000          Regular         0.051702
# 8511           FDF05       17.500          Low Fat         0.026980
# 8517           FDF53       20.750              reg         0.083607
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8     Frozen Foods   96.9726            OUT045                       2002
# ...

# %%
csv_data[csv_data.Item_Type.str.startswith('M')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 2              FDN15       17.500          Low Fat         0.016760      Meat
# 41             FDK43        9.800          Low Fat         0.026818      Meat
# 61             FDV27        7.970          Regular         0.040071      Meat
# 66             FDH19       19.350          Low Fat         0.033082      Meat
# 89             FDN27       20.850          Low Fat         0.039624      Meat
# ...              ...          ...              ...              ...       ...
# 8443           FDX15       17.200               LF         0.156542      Meat
# 8460           FDN39       19.350          Regular         0.065508      Meat
# 8470           FDW27        5.860          Regular         0.151088      Meat
# 8491           FDO03       10.395          Regular         0.037033      Meat
# 8513           FDH31       12.000          Regular         0.020407      Meat
#
# ...

# %%
names = ['M','F','Meat']
csv_data[csv_data.Item_Type.isin(names)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 2              FDN15       17.500          Low Fat         0.016760      Meat
# 41             FDK43        9.800          Low Fat         0.026818      Meat
# 61             FDV27        7.970          Regular         0.040071      Meat
# 66             FDH19       19.350          Low Fat         0.033082      Meat
# 89             FDN27       20.850          Low Fat         0.039624      Meat
# ...              ...          ...              ...              ...       ...
# 8443           FDX15       17.200               LF         0.156542      Meat
# 8460           FDN39       19.350          Regular         0.065508      Meat
# 8470           FDW27        5.860          Regular         0.151088      Meat
# 8491           FDO03       10.395          Regular         0.037033      Meat
# 8513           FDH31       12.000          Regular         0.020407      Meat
#
# ...

# %%
csv_data.query("Item_Type == 'Frozen Foods' and Item_Weight > 10")
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 24             FDR28       13.850          Regular         0.025896
# 51             FDM40       10.195          Low Fat         0.159804
# 78             FDL04       19.000          Low Fat         0.112557
# ...              ...          ...              ...              ...
# 8461           FDB17       13.150          Low Fat         0.036672
# 8477           FDC05       13.100          Regular         0.099343
# 8482           FDZ28       20.000          Regular         0.051702
# 8511           FDF05       17.500          Low Fat         0.026980
# 8517           FDF53       20.750              reg         0.083607
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8     Frozen Foods   96.9726            OUT045                       2002
# ...

# %%
print(csv_data.describe())
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
print(csv_data.describe(include='all'))
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  7060.000000             8523      8523.000000
# unique            1559          NaN                5              NaN
# top              FDW13          NaN          Low Fat              NaN
# freq                10          NaN             5089              NaN
# mean               NaN    12.857645              NaN         0.066132
# std                NaN     4.643456              NaN         0.051598
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.773750              NaN         0.026989
# 50%                NaN    12.600000              NaN         0.053931
# 75%                NaN    16.850000              NaN         0.094585
# max                NaN    21.350000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    8523  8523.000000              8523
# ...

# %%
csv_data.describe(include=[np.number])
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
csv_data.describe(exclude=['O'])
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
csv_data.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
csv_data.isna()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
print(csv_data.isnull().values.any())
# Out:
# True

# %%
print(csv_data.isna().values.any())
# Out:
# True

# %%
print(csv_data.duplicated().values.any())
# Out:
# False

# %%
csv_data.dropna()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# ...              ...          ...              ...              ...
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# ...

# %%
print(csv_data.isnull().values.any())
# Out:
# True

# %%
print(csv_data.isna().values.any())
# Out:
# True

# %%
csv_data.mean(numeric_only=True)
# Out:
# Item_Weight                    12.857645
# Item_Visibility                 0.066132
# Item_MRP                      140.992782
# Outlet_Establishment_Year    1997.831867
# Item_Outlet_Sales            2181.288914
# dtype: float64

# %%
csv_data.median(numeric_only=True)
# Out:
# Item_Weight                    12.600000
# Item_Visibility                 0.053931
# Item_MRP                      143.012800
# Outlet_Establishment_Year    1999.000000
# Item_Outlet_Sales            1794.331000
# dtype: float64

# %%
csv_data_clone = csv_data.copy()

# %%
data_filling=csv_data_clone.fillna(csv_data.mean(numeric_only=True))

# %%
print(data_filling.head(10))
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15     9.300000          Low Fat         0.016047
# 1           DRC01     5.920000          Regular         0.019278
# 2           FDN15    17.500000          Low Fat         0.016760
# 3           FDX07    19.200000          Regular         0.000000
# 4           NCD19     8.930000          Low Fat         0.000000
# 5           FDP36    10.395000          Regular         0.000000
# 6           FDO10    13.650000          Regular         0.012741
# 7           FDP10    12.857645          Low Fat         0.127470
# 8           FDH17    16.200000          Regular         0.016687
# 9           FDU28    19.200000          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
data_filling=csv_data_clone.fillna(csv_data.median(numeric_only=True))

# %%
print(data_filling.head(10))
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10       12.600          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
csv_data['Item_MRP'].astype('float')
# Out:
# 0       249.8092
# 1        48.2692
# 2       141.6180
# 3       182.0950
# 4        53.8614
#           ...
# 8518    214.5218
# 8519    108.1570
# 8520     85.1224
# 8521    103.1332
# 8522     75.4670
# Name: Item_MRP, Length: 8523, dtype: float64

# %%
csv_data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
csv_data['Item_MRP']=csv_data['Item_MRP'].astype('float')

# %%
csv_data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object
